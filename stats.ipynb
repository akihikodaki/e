# %% [markdown]
# # e

# %% [markdown]
# ## Initialization

# %%
# SPDX-License-Identifier: Apache-2.0

from bokeh.io import output_notebook
from bokeh.plotting import figure, show
import json
import statistics

def ipc(core):
    return core['instructions'] / core['cycles']

def load(name):
    with open(f'stats/{name}.json') as io:
        return json.load(io)

output_notebook()

with open('benchmarks') as io:
    names = [line[:-1] for line in io]

stats = [load(name) for name in names]
ipcs = [ipc(phases[0]['roi']['cores'][0]) for phases in stats]
stats[0]
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bb75840c-e05d-4cfc-af4b-3b6670ff5579">Loading BokehJS ...</span>
#     </div>
# [{'name': 'Simulation',
#   'roi': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 20.306637501760665,
#      'REFRESHES ISSUED': 10001,
#      'RQ ROW_BUFFER_HIT': 1447,
#      'RQ ROW_BUFFER_MISS': 106804,
#      'WQ ROW_BUFFER_HIT': 5207,
#      'WQ ROW_BUFFER_MISS': 10627}],
#    'LLC': {'LOAD': {'hit': [19370], 'miss': [88140], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [1260], 'miss': [3320], 'mshr_merge': [0]},
#     'RFO': {'hit': [2703], 'miss': [5035], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [2270], 'miss': [11760], 'mshr_merge': [0]},
#     'WRITE': {'hit': [21168], 'miss': [383], 'mshr_merge': [0]},
#     'miss latency': 178.28808940541978,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 156.29754794992536,
#      'cycles': 120011460,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 205444,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637,
#       'BRANCH_YIELD': 0}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [62481862],
#      'miss': [264687],
#      'mshr_merge': [102877]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 22.127421049378903,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [27537297],
#      'miss': [20501],
#      'mshr_merge': [14371]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 19.808482871125612,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [34065930],
#      'miss': [293229],
#      'mshr_merge': [95393]},
#     'PREFETCH': {'hit': [2153934], 'miss': [29099], 'mshr_merge': [19188]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [1012], 'miss': [14461], 'mshr_merge': [19]},
#     'WRITE': {'hit': [28295737], 'miss': [91654], 'mshr_merge': [68130]},
#     'miss latency': 93.0622488086961,
#     'prefetch issued': 2183025,
#     'prefetch requested': 2204252,
#     'useful prefetch': 1201,
#     'useless prefetch': 8727},
#    'cpu0_L1I': {'LOAD': {'hit': [27292770],
#      'miss': [265029],
#      'mshr_merge': [75831]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 11.808993752576665,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [279524], 'miss': [107510], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [5331], 'miss': [4580], 'mshr_merge': [0]},
#     'RFO': {'hit': [15786], 'miss': [7738], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [412], 'miss': [14030], 'mshr_merge': [0]},
#     'WRITE': {'hit': [60518], 'miss': [259], 'mshr_merge': [0]},
#     'miss latency': 160.71652114839776,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [160425], 'miss': [7515], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 379.84843646041253,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'sim': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 20.306637501760665,
#      'REFRESHES ISSUED': 10001,
#      'RQ ROW_BUFFER_HIT': 1447,
#      'RQ ROW_BUFFER_MISS': 106804,
#      'WQ ROW_BUFFER_HIT': 5207,
#      'WQ ROW_BUFFER_MISS': 10627}],
#    'LLC': {'LOAD': {'hit': [19370], 'miss': [88140], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [1260], 'miss': [3320], 'mshr_merge': [0]},
#     'RFO': {'hit': [2703], 'miss': [5035], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [2270], 'miss': [11760], 'mshr_merge': [0]},
#     'WRITE': {'hit': [21168], 'miss': [383], 'mshr_merge': [0]},
#     'miss latency': 178.28808940541978,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 156.29754794992536,
#      'cycles': 120011460,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 205444,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637,
#       'BRANCH_YIELD': 0}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [62481862],
#      'miss': [264687],
#      'mshr_merge': [102877]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 22.127421049378903,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [27537297],
#      'miss': [20501],
#      'mshr_merge': [14371]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 19.808482871125612,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [34065930],
#      'miss': [293229],
#      'mshr_merge': [95393]},
#     'PREFETCH': {'hit': [2153934], 'miss': [29099], 'mshr_merge': [19188]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [1012], 'miss': [14461], 'mshr_merge': [19]},
#     'WRITE': {'hit': [28295737], 'miss': [91654], 'mshr_merge': [68130]},
#     'miss latency': 93.0622488086961,
#     'prefetch issued': 2183025,
#     'prefetch requested': 2204252,
#     'useful prefetch': 1201,
#     'useless prefetch': 8727},
#    'cpu0_L1I': {'LOAD': {'hit': [27292770],
#      'miss': [265029],
#      'mshr_merge': [75831]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 11.808993752576665,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [279524], 'miss': [107510], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [5331], 'miss': [4580], 'mshr_merge': [0]},
#     'RFO': {'hit': [15786], 'miss': [7738], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [412], 'miss': [14030], 'mshr_merge': [0]},
#     'WRITE': {'hit': [60518], 'miss': [259], 'mshr_merge': [0]},
#     'miss latency': 160.71652114839776,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [160425], 'miss': [7515], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 379.84843646041253,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'traces': ['obj/traces/400.perlbench-41B.champsimtrace.xz']}]

# %% [markdown]
# ## IPC

# %% [markdown]
# ### Per benchmark

# %%
p = figure(y_range=names, height=2000)
p.hbar(y=names, right=ipcs)
p.x_range.start = 0
show(p)
# Out:
#   <div id="b8f25130-8dd4-4424-9bd9-25a2f884e7ee" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ### Mean

# %%
statistics.mean(ipcs)
# Out:
# 1.3926462253894485

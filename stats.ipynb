# %% [markdown]
# # e

# %% [markdown]
# ## Initialization

# %%
# SPDX-License-Identifier: Apache-2.0

from bokeh.io import output_notebook
from bokeh.plotting import figure, show
import json
import statistics

def ipc(core):
    return core['instructions'] / core['cycles']

def load(name):
    with open(f'stats/{name}.json') as io:
        return json.load(io)

output_notebook()

with open('benchmarks') as io:
    names = [line[:-1] for line in io]

stats = [load(name) for name in names]
ipcs = [ipc(phases[0]['roi']['cores'][0]) for phases in stats]
stats[0]
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a645d90e-7be0-492b-bcb3-9f5275070379">Loading BokehJS ...</span>
#     </div>
# [{'name': 'Simulation',
#   'roi': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 20.82296170039846,
#      'REFRESHES ISSUED': 12408,
#      'RQ ROW_BUFFER_HIT': 1203,
#      'RQ ROW_BUFFER_MISS': 103668,
#      'WQ ROW_BUFFER_HIT': 5124,
#      'WQ ROW_BUFFER_MISS': 10601}],
#    'LLC': {'LOAD': {'hit': [18853], 'miss': [88186], 'miss_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [2735], 'miss': [5052], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [2365], 'miss': [11636], 'miss_merge': [0]},
#     'WRITE': {'hit': [20990], 'miss': [377], 'miss_merge': [0]},
#     'miss latency': 177.05966689152598,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 53.21086889415365,
#      'cycles': 148896885,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 2004148,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [71929438],
#      'miss': [245811],
#      'miss_merge': [84459]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'miss latency': 21.927593088402993,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [3932654],
#      'miss': [19695],
#      'miss_merge': [13572]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'miss latency': 19.68087538788176,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [43509940],
#      'miss': [278705],
#      'miss_merge': [84076]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [1017], 'miss': [14456], 'miss_merge': [18]},
#     'WRITE': {'hit': [28296410], 'miss': [90981], 'miss_merge': [68244]},
#     'miss latency': 94.034567997101,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1I': {'LOAD': {'hit': [3726728],
#      'miss': [253212],
#      'miss_merge': [64189]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'miss latency': 11.634213825830718,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [276613], 'miss': [107039], 'miss_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [14950], 'miss': [7787], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [437], 'miss': [14001], 'miss_merge': [0]},
#     'WRITE': {'hit': [58264], 'miss': [289], 'miss_merge': [0]},
#     'miss latency': 160.0948526906038,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [159960], 'miss': [7515], 'miss_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'miss latency': 374.3944111776447,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'sim': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 20.82296170039846,
#      'REFRESHES ISSUED': 12408,
#      'RQ ROW_BUFFER_HIT': 1203,
#      'RQ ROW_BUFFER_MISS': 103668,
#      'WQ ROW_BUFFER_HIT': 5124,
#      'WQ ROW_BUFFER_MISS': 10601}],
#    'LLC': {'LOAD': {'hit': [18853], 'miss': [88186], 'miss_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [2735], 'miss': [5052], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [2365], 'miss': [11636], 'miss_merge': [0]},
#     'WRITE': {'hit': [20990], 'miss': [377], 'miss_merge': [0]},
#     'miss latency': 177.05966689152598,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 53.21086889415365,
#      'cycles': 148896885,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 2004148,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [71929438],
#      'miss': [245811],
#      'miss_merge': [84459]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'miss latency': 21.927593088402993,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [3932654],
#      'miss': [19695],
#      'miss_merge': [13572]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'miss latency': 19.68087538788176,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [43509940],
#      'miss': [278705],
#      'miss_merge': [84076]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [1017], 'miss': [14456], 'miss_merge': [18]},
#     'WRITE': {'hit': [28296410], 'miss': [90981], 'miss_merge': [68244]},
#     'miss latency': 94.034567997101,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1I': {'LOAD': {'hit': [3726728],
#      'miss': [253212],
#      'miss_merge': [64189]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'miss latency': 11.634213825830718,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [276613], 'miss': [107039], 'miss_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [14950], 'miss': [7787], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [437], 'miss': [14001], 'miss_merge': [0]},
#     'WRITE': {'hit': [58264], 'miss': [289], 'miss_merge': [0]},
#     'miss latency': 160.0948526906038,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [159960], 'miss': [7515], 'miss_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'miss_merge': [0]},
#     'miss latency': 374.3944111776447,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'traces': ['obj/traces/400.perlbench-41B.champsimtrace.xz']}]

# %% [markdown]
# ## IPC

# %% [markdown]
# ### Per benchmark

# %%
p = figure(y_range=names, height=2000)
p.hbar(y=names, right=ipcs)
p.x_range.start = 0
show(p)
# Out:
#   <div id="a42dec3d-893b-4b91-b5c8-ec523a9e7fc0" data-root-id="p1008" style="display: contents;"></div>

# %% [markdown]
# ### Mean

# %%
statistics.mean(ipcs)
# Out:
# 1.1326332860114066

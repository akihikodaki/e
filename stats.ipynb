# %% [markdown]
# # e

# %% [markdown]
# ## Initialization

# %%
# SPDX-License-Identifier: Apache-2.0

from bokeh.io import output_notebook
from bokeh.plotting import figure, show
import json
import statistics

def ipc(core):
    return core['instructions'] / core['cycles']

def load(name):
    with open(f'stats/{name}.json') as io:
        return json.load(io)

output_notebook()

with open('benchmarks') as io:
    names = [line[:-1] for line in io]

stats = [load(name) for name in names]
ipcs = [ipc(phases[0]['roi']['cores'][0]) for phases in stats]
stats[0]
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="da56db08-b650-4adf-9136-cc5ec00a494f">Loading BokehJS ...</span>
#     </div>
# [{'name': 'Simulation',
#   'roi': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 21.12448921059432,
#      'REFRESHES ISSUED': 11620,
#      'RQ ROW_BUFFER_HIT': 1307,
#      'RQ ROW_BUFFER_MISS': 94180,
#      'WQ ROW_BUFFER_HIT': 5070,
#      'WQ ROW_BUFFER_MISS': 10451}],
#    'LLC': {'LOAD': {'hit': [19114], 'miss': [87354], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [2707], 'miss': [4946], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [1857], 'miss': [3189], 'mshr_merge': [0]},
#     'WRITE': {'hit': [20716], 'miss': [358], 'mshr_merge': [0]},
#     'miss latency': 176.7685060565276,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 50.93792885661435,
#      'cycles': 139438756,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 2004149,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [58165697],
#      'miss': [209387],
#      'mshr_merge': [48021]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 10.55889716544997,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [3349210],
#      'miss': [17325],
#      'mshr_merge': [11202]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 12.9145843540748,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [34438273],
#      'miss': [233829],
#      'mshr_merge': [40583]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [543], 'miss': [7416], 'mshr_merge': [0]},
#     'WRITE': {'hit': [27233119], 'miss': [92261], 'mshr_merge': [69712]},
#     'miss latency': 89.24864366003467,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1I': {'LOAD': {'hit': [3637812],
#      'miss': [252413],
#      'mshr_merge': [63365]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 11.380580593288476,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [275826], 'miss': [106468], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [14896], 'miss': [7653], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [2370], 'miss': [5046], 'mshr_merge': [0]},
#     'WRITE': {'hit': [57806], 'miss': [265], 'mshr_merge': [0]},
#     'miss latency': 157.6101631053654,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [159974], 'miss': [7515], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 124.77924151696607,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'sim': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 21.12448921059432,
#      'REFRESHES ISSUED': 11620,
#      'RQ ROW_BUFFER_HIT': 1307,
#      'RQ ROW_BUFFER_MISS': 94180,
#      'WQ ROW_BUFFER_HIT': 5070,
#      'WQ ROW_BUFFER_MISS': 10451}],
#    'LLC': {'LOAD': {'hit': [19114], 'miss': [87354], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [2707], 'miss': [4946], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [1857], 'miss': [3189], 'mshr_merge': [0]},
#     'WRITE': {'hit': [20716], 'miss': [358], 'mshr_merge': [0]},
#     'miss latency': 176.7685060565276,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 50.93792885661435,
#      'cycles': 139438756,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 2004149,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [58165697],
#      'miss': [209387],
#      'mshr_merge': [48021]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 10.55889716544997,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [3349210],
#      'miss': [17325],
#      'mshr_merge': [11202]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 12.9145843540748,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [34438273],
#      'miss': [233829],
#      'mshr_merge': [40583]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [543], 'miss': [7416], 'mshr_merge': [0]},
#     'WRITE': {'hit': [27233119], 'miss': [92261], 'mshr_merge': [69712]},
#     'miss latency': 89.24864366003467,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1I': {'LOAD': {'hit': [3637812],
#      'miss': [252413],
#      'mshr_merge': [63365]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 11.380580593288476,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [275826], 'miss': [106468], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [14896], 'miss': [7653], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [2370], 'miss': [5046], 'mshr_merge': [0]},
#     'WRITE': {'hit': [57806], 'miss': [265], 'mshr_merge': [0]},
#     'miss latency': 157.6101631053654,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [159974], 'miss': [7515], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 124.77924151696607,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'traces': ['obj/traces/400.perlbench-41B.champsimtrace.xz']}]

# %% [markdown]
# ## IPC

# %% [markdown]
# ### Per benchmark

# %%
p = figure(y_range=names, height=2000)
p.hbar(y=names, right=ipcs)
p.x_range.start = 0
show(p)
# Out:
#   <div id="e86d8b66-7374-4690-bfc4-e599a50cef77" data-root-id="p2590" style="display: contents;"></div>

# %% [markdown]
# ### Mean

# %%
statistics.mean(ipcs)
# Out:
# 1.2189054009315865

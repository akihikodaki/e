# %% [markdown]
# # e

# %% [markdown]
# ## Initialization

# %%
# SPDX-License-Identifier: Apache-2.0

from bokeh.io import output_notebook
from bokeh.plotting import figure, show
import json
import statistics

def ipc(core):
    return core['instructions'] / core['cycles']

def load(name):
    with open(f'stats/{name}.json') as io:
        return json.load(io)

output_notebook()

with open('benchmarks') as io:
    names = [line[:-1] for line in io]

stats = [load(name) for name in names]
ipcs = [ipc(phases[0]['roi']['cores'][0]) for phases in stats]
stats[0]
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="adeac804-7802-4de6-a096-232cd437cfe1">Loading BokehJS ...</span>
#     </div>
# [{'name': 'Simulation',
#   'roi': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 20.687642506687265,
#      'REFRESHES ISSUED': 12407,
#      'RQ ROW_BUFFER_HIT': 1204,
#      'RQ ROW_BUFFER_MISS': 103719,
#      'WQ ROW_BUFFER_HIT': 5186,
#      'WQ ROW_BUFFER_MISS': 10565}],
#    'LLC': {'LOAD': {'hit': [18810], 'miss': [88197], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [2736], 'miss': [5072], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [2349], 'miss': [11654], 'mshr_merge': [0]},
#     'WRITE': {'hit': [20962], 'miss': [383], 'mshr_merge': [0]},
#     'miss latency': 177.263717167113,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 53.20965070761819,
#      'cycles': 148883795,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 2004148,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [71921644],
#      'miss': [245842],
#      'mshr_merge': [84505]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 21.895206927115293,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [3932429],
#      'miss': [19708],
#      'mshr_merge': [13585]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 19.33039359790952,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [43502508],
#      'miss': [278919],
#      'mshr_merge': [84305]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [1018], 'miss': [14455], 'mshr_merge': [18]},
#     'WRITE': {'hit': [28296564], 'miss': [90827], 'mshr_merge': [68076]},
#     'miss latency': 94.11938637285269,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1I': {'LOAD': {'hit': [3726503],
#      'miss': [253129],
#      'mshr_merge': [64106]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 11.695920602254752,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [276630], 'miss': [107007], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [14943], 'miss': [7808], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [434], 'miss': [14003], 'mshr_merge': [0]},
#     'WRITE': {'hit': [58287], 'miss': [267], 'mshr_merge': [0]},
#     'miss latency': 160.37356780416005,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [159945], 'miss': [7515], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 373.3811044577512,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'sim': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 20.687642506687265,
#      'REFRESHES ISSUED': 12407,
#      'RQ ROW_BUFFER_HIT': 1204,
#      'RQ ROW_BUFFER_MISS': 103719,
#      'WQ ROW_BUFFER_HIT': 5186,
#      'WQ ROW_BUFFER_MISS': 10565}],
#    'LLC': {'LOAD': {'hit': [18810], 'miss': [88197], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [2736], 'miss': [5072], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [2349], 'miss': [11654], 'mshr_merge': [0]},
#     'WRITE': {'hit': [20962], 'miss': [383], 'mshr_merge': [0]},
#     'miss latency': 177.263717167113,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 53.20965070761819,
#      'cycles': 148883795,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 2004148,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [71921644],
#      'miss': [245842],
#      'mshr_merge': [84505]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 21.895206927115293,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [3932429],
#      'miss': [19708],
#      'mshr_merge': [13585]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 19.33039359790952,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [43502508],
#      'miss': [278919],
#      'mshr_merge': [84305]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [1018], 'miss': [14455], 'mshr_merge': [18]},
#     'WRITE': {'hit': [28296564], 'miss': [90827], 'mshr_merge': [68076]},
#     'miss latency': 94.11938637285269,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1I': {'LOAD': {'hit': [3726503],
#      'miss': [253129],
#      'mshr_merge': [64106]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 11.695920602254752,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [276630], 'miss': [107007], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [14943], 'miss': [7808], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [434], 'miss': [14003], 'mshr_merge': [0]},
#     'WRITE': {'hit': [58287], 'miss': [267], 'mshr_merge': [0]},
#     'miss latency': 160.37356780416005,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [159945], 'miss': [7515], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 373.3811044577512,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'traces': ['obj/traces/400.perlbench-41B.champsimtrace.xz']}]

# %% [markdown]
# ## IPC

# %% [markdown]
# ### Per benchmark

# %%
p = figure(y_range=names, height=2000)
p.hbar(y=names, right=ipcs)
p.x_range.start = 0
show(p)
# Out:
#   <div id="db2850e9-ef5a-409b-8f2c-b9465b4e0cad" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ### Mean

# %%
statistics.mean(ipcs)
# Out:
# 1.1325877487082605

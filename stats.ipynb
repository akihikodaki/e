# %% [markdown]
# # e

# %% [markdown]
# ## Initialization

# %%
# SPDX-License-Identifier: Apache-2.0

from bokeh.io import output_notebook
from bokeh.plotting import figure, show
import json
import statistics

def ipc(core):
    return core['instructions'] / core['cycles']

def load(name):
    with open(f'stats/{name}.json') as io:
        return json.load(io)

output_notebook()

with open('benchmarks') as io:
    names = [line[:-1] for line in io]

stats = [load(name) for name in names]
ipcs = [ipc(phases[0]['roi']['cores'][0]) for phases in stats]
stats[0]
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e5d6057c-265c-42cf-a6c9-7b1294087014">Loading BokehJS ...</span>
#     </div>
# [{'name': 'Simulation',
#   'roi': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 20.737536828061593,
#      'REFRESHES ISSUED': 11778,
#      'RQ ROW_BUFFER_HIT': 1206,
#      'RQ ROW_BUFFER_MISS': 103812,
#      'WQ ROW_BUFFER_HIT': 5008,
#      'WQ ROW_BUFFER_MISS': 10796}],
#    'LLC': {'LOAD': {'hit': [19636], 'miss': [88317], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [2612], 'miss': [5086], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [2418], 'miss': [11615], 'mshr_merge': [0]},
#     'WRITE': {'hit': [20825], 'miss': [408], 'mshr_merge': [0]},
#     'miss latency': 177.22783753533284,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 50.93935536042065,
#      'cycles': 141332261,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 2004149,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [58165222],
#      'miss': [209892],
#      'mshr_merge': [48543]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 21.84502537976684,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [3349699],
#      'miss': [17329],
#      'mshr_merge': [11206]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 19.650334803201044,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [34436776],
#      'miss': [235348],
#      'mshr_merge': [40730]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [1020], 'miss': [14453], 'mshr_merge': [17]},
#     'WRITE': {'hit': [27232783], 'miss': [92616], 'mshr_merge': [69867]},
#     'miss latency': 94.15658986294396,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1I': {'LOAD': {'hit': [3638269],
#      'miss': [252460],
#      'mshr_merge': [63417]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 11.82072332749692,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [275708], 'miss': [107953], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [15051], 'miss': [7698], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [403], 'miss': [14033], 'mshr_merge': [0]},
#     'WRITE': {'hit': [58269], 'miss': [275], 'mshr_merge': [0]},
#     'miss latency': 159.52915919636192,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [159957], 'miss': [7515], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 372.5719228210246,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'sim': {'DRAM': [{'AVG DBUS CONGESTED CYCLE': 20.737536828061593,
#      'REFRESHES ISSUED': 11778,
#      'RQ ROW_BUFFER_HIT': 1206,
#      'RQ ROW_BUFFER_MISS': 103812,
#      'WQ ROW_BUFFER_HIT': 5008,
#      'WQ ROW_BUFFER_MISS': 10796}],
#    'LLC': {'LOAD': {'hit': [19636], 'miss': [88317], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [2612], 'miss': [5086], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [2418], 'miss': [11615], 'mshr_merge': [0]},
#     'WRITE': {'hit': [20825], 'miss': [408], 'mshr_merge': [0]},
#     'miss latency': 177.22783753533284,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cores': [{'Avg ROB occupancy at mispredict': 50.93935536042065,
#      'cycles': 141332261,
#      'instructions': 200000003,
#      'mispredict': {'BRANCH_CONDITIONAL': 2004149,
#       'BRANCH_DIRECT_CALL': 906,
#       'BRANCH_DIRECT_JUMP': 2374,
#       'BRANCH_INDIRECT': 65187,
#       'BRANCH_INDIRECT_CALL': 37904,
#       'BRANCH_RETURN': 1637}}],
#    'cpu0_DTLB': {'LOAD': {'hit': [58165222],
#      'miss': [209892],
#      'mshr_merge': [48543]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 21.84502537976684,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_ITLB': {'LOAD': {'hit': [3349699],
#      'miss': [17329],
#      'mshr_merge': [11206]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 19.650334803201044,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1D': {'LOAD': {'hit': [34436776],
#      'miss': [235348],
#      'mshr_merge': [40730]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [1020], 'miss': [14453], 'mshr_merge': [17]},
#     'WRITE': {'hit': [27232783], 'miss': [92616], 'mshr_merge': [69867]},
#     'miss latency': 94.15658986294396,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L1I': {'LOAD': {'hit': [3638269],
#      'miss': [252460],
#      'mshr_merge': [63417]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 11.82072332749692,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_L2C': {'LOAD': {'hit': [275708], 'miss': [107953], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [15051], 'miss': [7698], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [403], 'miss': [14033], 'mshr_merge': [0]},
#     'WRITE': {'hit': [58269], 'miss': [275], 'mshr_merge': [0]},
#     'miss latency': 159.52915919636192,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0},
#    'cpu0_STLB': {'LOAD': {'hit': [159957], 'miss': [7515], 'mshr_merge': [0]},
#     'PREFETCH': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'RFO': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'TRANSLATION': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'WRITE': {'hit': [0], 'miss': [0], 'mshr_merge': [0]},
#     'miss latency': 372.5719228210246,
#     'prefetch issued': 0,
#     'prefetch requested': 0,
#     'useful prefetch': 0,
#     'useless prefetch': 0}},
#   'traces': ['obj/traces/400.perlbench-41B.champsimtrace.xz']}]

# %% [markdown]
# ## IPC

# %% [markdown]
# ### Per benchmark

# %%
p = figure(y_range=names, height=2000)
p.hbar(y=names, right=ipcs)
p.x_range.start = 0
show(p)
# Out:
#   <div id="a95073b0-3432-4e51-aad8-a6aea5e8eec6" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ### Mean

# %%
statistics.mean(ipcs)
# Out:
# 1.1997965861325723
